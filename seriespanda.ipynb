# %%
import pandas as pd

# %%
a = pd.Series([1,23,4,5,6])
print(a)
#index
print(a[0])
# Out:
# 0     1
# 1    23
# 2     4
# 3     5
# 4     6
# dtype: int64
# 1

# %%
s= pd.Series([23,24,56,43] , index=["adam","hari","pandu","reddy"])
print(s)

print(s["adam"])
print(s["hari"])
print(s[0])
# Out:
# adam     23
# hari     24
# pandu    56
# reddy    43
# dtype: int64
# 23
# 24
# 23
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10404\2217774271.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[0])

# %%
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([1,2,3,4,5])
#mutable
s1[0]=100

print(s1+s2)

#size cannot be mutable (immutable sizes)
# Out:
# 0    101
# 1      4
# 2      6
# 3      8
# 4     10
# dtype: int64
