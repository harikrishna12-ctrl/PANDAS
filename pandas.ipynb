# %%
import pandas as pd

# %%
info = {
      "name" : ["hari","pandu"],
      "cgpa"  : [9.3,10]
   }
df = pd.DataFrame(info)
print(df)
print(df.index)
print(df.columns)
# Out:
#     name  cgpa
# 0   hari   9.3
# 1  pandu  10.0
# RangeIndex(start=0, stop=2, step=1)
# Index(['name', 'cgpa'], dtype='object')
