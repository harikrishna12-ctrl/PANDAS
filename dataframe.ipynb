# %%
import pandas as pd

# %%
info = {
      "name" : ["hari","pandu"],
      "cgpa"  : [9.3,10]
   }

df = pd.DataFrame(info)
print(df)
# Out:
#     name  cgpa
# 0   hari   9.3
# 1  pandu  10.0

# %%
df
# Out:
#     name  cgpa
# 0   hari   9.3
# 1  pandu  10.0

# %%
#second way to create a pandas dataframe
df = pd.DataFrame([["adam",24],["bob",23]])
print(df)
# Out:
#       0   1
# 0  adam  24
# 1   bob  23

# %%
df
# Out:
#       0   1
# 0  adam  24
# 1   bob  23

# %%
#we can create using numpy arrays
